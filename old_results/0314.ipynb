# %%
from drawing import *

files = ['results_HGP_n320_m=1_rate0.0-1.0_deterministic_assignment.json']

list_of_res = read_jsons(files)
plot_multiple_data(list_of_res=list_of_res, max_e=0.55, min_e=0, step=0.01, n=320,k=4,save=False)
# Out:
# 0

# %%
files2 = ['results_HGP_n320_m=2_rate0.0-1.0_deterministic_assignment.json', 'results_HGP_n320_m=2_rate0.0-1.0_random_assignment.json', 'results_HGP_n320_m=2_rate0.0-1.0_row_col_assignment.json']
files4 = ['results_HGP_n320_m=4_rate0.0-0.9977_deterministic_assignment.json', 'results_HGP_n320_m=4_rate0.0-1.0_random_assignment.json', 'results_HGP_n320_m=4_rate0.0-0.9996_row_col_assignment.json' ]
files8 = ['results_HGP_n320_m=8_rate0.0-0.8768_deterministic_assignment.json', 'results_HGP_n320_m=8_rate0.0-0.9944_random_assignment.json', 'results_HGP_n320_m=8_rate0.0-0.9945_row_col_assignment.json']
files16 = ['results_HGP_n320_m=16_rate0.0-0.3925_deterministic_assignment.json','results_HGP_n320_m=16_rate0.0-0.9639_random_assignment.json', 'results_HGP_n320_m=16_rate0.0-0.9634_row_col_assignment.json']

# 'results_HGP_n320_m=16_rate0.0-0.3925_deterministic_assignment.json'

# %%
list_of_res = read_jsons(files + files2)
plot_multiple_data(list_of_res=list_of_res, max_e=0.55, min_e=0, step=0.01, n=320,k=4,save=False,log = False)
# Out:
# 0

# %%
list_of_res = read_jsons(files + files4)
plot_multiple_data(list_of_res=list_of_res, max_e=0.55, min_e=0, step=0.01, n=320,k=4,save=False)
# Out:
# 0

# %%
list_of_res = read_jsons(files + files8)
plot_multiple_data(list_of_res=list_of_res, max_e=0.55, min_e=0, step=0.01, n=320,k=4,save=False)
# Out:
# 0

# %%
list_of_res = read_jsons(files + files16)
plot_multiple_data(list_of_res=list_of_res, max_e=0.55, min_e=0, step=0.01, n=320,k=4,save=False,log =False)
# Out:
# 0

# %%
list_of_res = read_jsons(files + [files2[0],files4[0],files8[0],files16[0]])
plot_multiple_data(list_of_res=list_of_res, max_e=0.55, min_e=0, step=0.01, n=320,k=4,save=False)
# Out:
# 0

# %%
list_of_res = read_jsons(files + [files2[1],files4[1],files8[1],files16[1]])
plot_multiple_data(list_of_res=list_of_res, max_e=0.55, min_e=0, step=0.01, n=320,k=4,save=False)
# Out:
# 0

# %%
list_of_res = read_jsons(files + [files2[2],files4[2],files8[2],files16[2]])
plot_multiple_data(list_of_res=list_of_res, max_e=0.55, min_e=0, step=0.01, n=320,k=4,save=False)
# Out:
# 0
